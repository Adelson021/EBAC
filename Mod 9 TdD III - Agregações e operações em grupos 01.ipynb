# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df = pd.read_csv('SINASC_RO_2019.csv')
df.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1        2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2        3        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3        4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4        5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27028 entries, 0 to 27027
# Data columns (total 69 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORIGEM        27028 non-null  int64
#  1   CODESTAB      26913 non-null  float64
#  2   CODMUNNASC    27028 non-null  int64
#  3   LOCNASC       27028 non-null  int64
#  4   IDADEMAE      27028 non-null  int64
#  5   ESTCIVMAE     26711 non-null  float64
#  6   ESCMAE        26716 non-null  object
#  7   CODOCUPMAE    24121 non-null  float64
#  8   QTDFILVIVO    25455 non-null  float64
#  9   QTDFILMORT    24930 non-null  float64
#  10  CODMUNRES     27028 non-null  int64
#  11  GESTACAO      25796 non-null  object
#  12  GRAVIDEZ      26949 non-null  object
#  13  PARTO         26979 non-null  object
#  14  CONSULTAS     27028 non-null  int64
#  15  DTNASC        27028 non-null  object
#  16  HORANASC      27007 non-null  float64
#  17  SEXO          27024 non-null  object
#  18  APGAR1        26932 non-null  float64
#  19  APGAR5        26925 non-null  float64
#  20  RACACOR       26381 non-null  object
#  21  PESO          27028 non-null  int64
#  22  IDANOMAL      26437 non-null  float64
#  23  DTCADASTRO    27028 non-null  object
#  24  CODANOMAL     214 non-null    object
#  25  NUMEROLOTE    27028 non-null  int64
#  26  VERSAOSIST    27028 non-null  object
#  27  DTRECEBIM     27028 non-null  object
#  28  DIFDATA       27028 non-null  int64
#  29  DTRECORIGA    0 non-null      float64
#  30  NATURALMAE    26730 non-null  float64
#  31  CODMUNNATU    26730 non-null  float64
#  32  CODUFNATU     26730 non-null  float64
#  33  ESCMAE2010    26779 non-null  float64
#  34  SERIESCMAE    14318 non-null  float64
#  35  DTNASCMAE     26988 non-null  float64
#  36  RACACORMAE    26367 non-null  float64
#  37  QTDGESTANT    25816 non-null  float64
#  38  QTDPARTNOR    25149 non-null  float64
#  39  QTDPARTCES    25237 non-null  float64
#  40  IDADEPAI      7607 non-null   float64
#  41  DTULTMENST    16956 non-null  float64
#  42  SEMAGESTAC    25790 non-null  float64
#  43  TPMETESTIM    25790 non-null  float64
#  44  CONSPRENAT    26098 non-null  float64
#  45  MESPRENAT     24161 non-null  float64
#  46  TPAPRESENT    26763 non-null  float64
#  47  STTRABPART    26081 non-null  float64
#  48  STCESPARTO    26281 non-null  float64
#  49  TPNASCASSI    26967 non-null  float64
#  50  TPFUNCRESP    26961 non-null  float64
#  51  TPDOCRESP     27014 non-null  float64
#  52  DTDECLARAC    26976 non-null  float64
#  53  ESCMAEAGR1    26779 non-null  float64
#  54  STDNEPIDEM    27028 non-null  int64
#  55  STDNNOVA      27028 non-null  int64
#  56  CODPAISRES    27028 non-null  int64
#  57  TPROBSON      27028 non-null  int64
#  58  PARIDADE      27028 non-null  int64
#  59  KOTELCHUCK    27028 non-null  int64
#  60  CONTADOR      27028 non-null  int64
#  61  munResStatus  27028 non-null  object
#  62  munResTipo    27028 non-null  object
#  63  munResNome    27028 non-null  object
#  64  munResUf      27028 non-null  object
#  65  munResLat     27027 non-null  float64
#  66  munResLon     27027 non-null  float64
#  67  munResAlt     27027 non-null  float64
#  68  munResArea    27027 non-null  float64
# dtypes: float64(38), int64(16), object(15)
# memory usage: 14.2+ MB

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
# Calcular a idade média das mães e dos pais por município
media_idade_maes = df.groupby('munResNome')['IDADEMAE'].mean()
media_idade_pais = df.groupby('munResNome')['IDADEPAI'].mean()

# Juntar as duas séries em um único DataFrame
media_idades = pd.DataFrame({'Media_Idade_Mae': media_idade_maes, 'Media_Idade_Pai': media_idade_pais})

media_idades
# Out:
#                            Media_Idade_Mae  Media_Idade_Pai
# munResNome
# Alta Floresta D'Oeste            25.991826        29.548701
# Alto Alegre dos Parecis          24.844156        29.179104
# Alto Paraíso                     24.960177        28.833333
# Alvorada D'Oeste                 25.770732        30.757282
# Ariquemes                        25.607866        32.466667
# Buritis                          25.559177        30.812500
# Cabixi                           26.037500        34.333333
# Cacaulândia                      25.546667        36.333333
# Cacoal                           26.890102        30.931854
# Campo Novo de Rondônia           24.825301        30.500000
# Candeias do Jamari               25.243323        29.894737
# Castanheiras                     27.281250        30.392857
# Cerejeiras                       27.240506        31.652778
# Chupinguaia                      25.333333        29.629630
# Colorado do Oeste                27.602804        34.354839
# Corumbiara                       24.716535        32.470588
# Costa Marques                    24.412017        30.613636
# Cujubim                          24.482927        31.400000
# Espigão D'Oeste                  26.093333        31.198113
# Governador Jorge Teixeira        24.401786        29.222222
# Guajará-Mirim                    25.462228        30.470588
# Itapuã do Oeste                  26.064220        42.500000
# Jaru                             25.982974        32.197183
# Ji-Paraná                        26.361137        31.132239
# Machadinho D'Oeste               25.480000        31.326923
# Ministro Andreazza               27.904762        33.849315
# Mirante da Serra                 26.304878        32.154762
# Monte Negro                      25.648241        34.678571
# Município ignorado - RO          24.000000        22.000000
# Nova Brasilândia D'Oeste         26.222222        30.520833
# Nova Mamoré                      25.326389        31.692308
# Nova União                       26.894231        31.371429
# Novo Horizonte do Oeste          26.938776        31.588235
# Ouro Preto do Oeste              26.375594        31.233244
# Parecis                          26.454545        32.473684
# Pimenta Bueno                    25.199675        29.745174
# Pimenteiras do Oeste             25.075000        35.600000
# Porto Velho                      26.312670        32.352679
# Presidente Médici                25.796053        30.150754
# Primavera de Rondônia            27.023256        31.888889
# Rio Crespo                       26.660000        28.000000
# Rolim de Moura                   26.600863        30.360479
# Santa Luzia D'Oeste              26.121212        30.703297
# Seringueiras                     24.910714        30.500000
# São Felipe D'Oeste               26.481481        31.395833
# São Francisco do Guaporé         25.660066        31.638889
# São Miguel do Guaporé            25.926346        32.666667
# Teixeirópolis                    26.031250        31.500000
# Theobroma                        25.536082        30.083333
# Urupá                            26.688235        31.008929
# Vale do Anari                    26.096774        34.000000
# Vale do Paraíso                  25.679012        29.976744
# Vilhena                          26.433962        34.152941

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
data_aniversario = '25/06'  # Substitua pela data do seu aniversário

# Converter a coluna DTNASC para o tipo datetime
df['DTNASC'] = pd.to_datetime(df['DTNASC'], dayfirst=True)

# Filtrar os nascimentos na data do aniversário
df_aniversario = df[df['DTNASC'].dt.strftime('%d/%m') == data_aniversario]
df_aniversario
# Out:
# C:\Users\Joel\AppData\Local\Temp\ipykernel_8600\828236734.py:4: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['DTNASC'] = pd.to_datetime(df['DTNASC'], dayfirst=True)
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 60          1  2679477.0      110001        1        23        5.0
# 61          1  2679477.0      110001        1        22        2.0
# 1181        1  2515601.0      110002        1        35        2.0
# 1217        1  2515598.0      110002        1        38        1.0
# 1257        1  2515504.0      110002        1        37        1.0
# ...       ...        ...         ...      ...       ...        ...
# 13296       1  3156516.0      110130        1        18        2.0
# 13572       1  7218656.0      110149        1        23        5.0
# 13716       1  2000733.0      120040        1        23        2.0
# 13717       1  2000733.0      120040        1        22        5.0
# 13752       1  2604388.0      510340        1        36        2.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 60         8 a 11 anos    999992.0         1.0         1.0  ...           5
# 61     12 anos ou mais    421125.0         1.0         0.0  ...           5
# 1181   12 anos ou mais    999992.0         1.0         2.0  ...           5
# 1217   12 anos ou mais    999992.0         2.0         0.0  ...           5
# 1257   12 anos ou mais    411010.0         2.0         1.0  ...           4
# ...                ...         ...         ...         ...  ...         ...
# 13296      8 a 11 anos    622020.0         0.0         0.0  ...           5
# 13572      8 a 11 anos    999992.0         2.0         0.0  ...           2
# 13716       4 a 7 anos    999992.0         1.0         0.0  ...           5
# 13717      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 13752  12 anos ou mais    411010.0         0.0         0.0  ...           3
#
#       CONTADOR munResStatus munResTipo                munResNome  munResUf  \
# 60          61        ATIVO      MUNIC     Alta Floresta D'Oeste  Rondônia
# 61          62        ATIVO      MUNIC     Alta Floresta D'Oeste  Rondônia
# 1181      1188        ATIVO      MUNIC                 Ariquemes  Rondônia
# 1217      1224        ATIVO      MUNIC               Monte Negro  Rondônia
# 1257      1264        ATIVO      MUNIC                 Ariquemes  Rondônia
# ...        ...          ...        ...                       ...       ...
# 13296    13428        ATIVO      MUNIC          Alvorada D'Oeste  Rondônia
# 13572    13704        ATIVO      MUNIC  São Francisco do Guaporé  Rondônia
# 13716    21062        ATIVO      MUNIC               Porto Velho  Rondônia
# 13717    21067        ATIVO      MUNIC               Porto Velho  Rondônia
# 13752  1392406        ATIVO      MUNIC                 Ji-Paraná  Rondônia
#
#        munResLat munResLon  munResAlt  munResArea
# 60     -11.93554 -61.99982      338.0    7067.025
# 61     -11.93554 -61.99982      338.0    7067.025
# 1181    -9.90846 -63.03327      139.0    4426.571
# 1217   -10.26310 -63.29556      155.0    1931.378
# 1257    -9.90846 -63.03327      139.0    4426.571
# ...          ...       ...        ...         ...
# 13296  -11.34413 -62.27727      182.0    3029.189
# 13572  -12.06380 -63.57086      166.0   10959.767
# 13716   -8.76889 -63.83145       87.0   34096.394
# 13717   -8.76889 -63.83145       87.0   34096.394
# 13752  -10.88205 -61.94509      157.0    6896.648
#
# [90 rows x 69 columns]

# %%
# Calcular o peso médio dos bebês por sexo e faixa de escolaridade da mãe
peso_medio = df_aniversario.groupby(['SEXO', 'ESCMAE'])['PESO'].mean().unstack()
peso_medio
# Out:
# ESCMAE     12 anos ou mais  4 a 7 anos  8 a 11 anos
# SEXO
# Feminino       3224.705882     3384.00  3284.958333
# Masculino      3225.769231     3358.75  3278.888889

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
# Filtrar os dados para o ano de 2019
df_2019 = df[df['DTNASC'].dt.year == 2019]
df_2019
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0           1  2679477.0      110001        1        19        5.0
# 1           1  2679477.0      110001        1        29        2.0
# 2           1  2679477.0      110001        1        37        9.0
# 3           1  2516500.0      110001        1        30        5.0
# 4           1  2516500.0      110001        1        30        2.0
# ...       ...        ...         ...      ...       ...        ...
# 27023       1  2604388.0      510340        1        32        2.0
# 27024       1  2752654.0      510675        1        19        1.0
# 27025       1  9659366.0      510787        1        24        2.0
# 27026       1  9659366.0      510787        1        21        2.0
# 27027       1  2795655.0      510792        1        18        5.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0          8 a 11 anos         NaN         0.0         0.0  ...           5
# 1          8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2          8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3      12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4          8 a 11 anos    999992.0         1.0         0.0  ...           5
# ...                ...         ...         ...         ...  ...         ...
# 27023  12 anos ou mais    333115.0         1.0         0.0  ...           5
# 27024      8 a 11 anos    999992.0         0.0         0.0  ...           5
# 27025      8 a 11 anos    421125.0         0.0         1.0  ...           5
# 27026      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 27027      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#       CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0            1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1            2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2            3        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3            4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4            5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...        ...          ...        ...                      ...       ...
# 27023  2767632        ATIVO      MUNIC                  Vilhena  Rondônia
# 27024  2772678        ATIVO      MUNIC              Chupinguaia  Rondônia
# 27025  2776905        ATIVO      MUNIC                  Vilhena  Rondônia
# 27026  2777105        ATIVO      MUNIC                  Vilhena  Rondônia
# 27027  2780269        ATIVO      MUNIC  Novo Horizonte do Oeste  Rondônia
#
#        munResLat munResLon  munResAlt  munResArea
# 0      -11.93554 -61.99982      338.0    7067.025
# 1      -11.93554 -61.99982      338.0    7067.025
# 2      -11.93554 -61.99982      338.0    7067.025
# 3      -12.13178 -61.85308      397.0    3958.273
# 4      -11.93554 -61.99982      338.0    7067.025
# ...          ...       ...        ...         ...
# 27023  -12.74137 -60.13858      595.0   11518.915
# 27024  -12.55684 -60.90185      340.0    5126.723
# 27025  -12.74137 -60.13858      595.0   11518.915
# 27026  -12.74137 -60.13858      595.0   11518.915
# 27027  -11.70974 -61.99439      230.0     843.446
#
# [27028 rows x 69 columns]

# %%
# Encontrar o município com o menor número de nascimentos
municipio_menos_nascimentos = df_2019['munResNome'].value_counts().idxmin()
municipio_menos_nascimentos
# Out:
# 'Município ignorado - RO'

# %%
# Filtrar os dados para esse município
df_municipio = df_2019[df_2019['munResNome'] == municipio_menos_nascimentos]
df_municipio
# Out:
#       ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 1863       1  2496046.0      110004        1        24        5.0
#
#            ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 1863  8 a 11 anos    752105.0         1.0         1.0  ...           1
#
#      CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 1863     1881        IGNOR      IGNOR  Município ignorado - RO  Rondônia
#
#       munResLat munResLon  munResAlt  munResArea
# 1863        NaN       NaN        NaN         NaN
#
# [1 rows x 69 columns]

# %%
# Calcular idade média, máxima e mínima das mães nesse município
idade_maes_media = df_municipio['IDADEMAE'].mean()
idade_maes_mediana = df_municipio['IDADEMAE'].median()
idade_maes_max = df_municipio['IDADEMAE'].max()
idade_maes_min = df_municipio['IDADEMAE'].min()

print(f"Idade das mães - Média: {idade_maes_media:.2f}, Mediana: {idade_maes_mediana}, Máxima: {idade_maes_max}, Mínima: {idade_maes_min}")
# Out:
# Idade das mães - Média: 24.00, Mediana: 24.0, Máxima: 24, Mínima: 24

# %%
# Calcular idade média, máxima e mínima dos pais nesse município
idade_pais_media = df_municipio['IDADEPAI'].mean()
idade_pais_mediana = df_municipio['IDADEPAI'].median()
idade_pais_max = df_municipio['IDADEPAI'].max()
idade_pais_min = df_municipio['IDADEPAI'].min()

print(f"Idade dos pais - Média: {idade_pais_media:.2f}, Mediana: {idade_pais_mediana}, Máxima: {idade_pais_max}, Mínima: {idade_pais_min}")
# Out:
# Idade dos pais - Média: 22.00, Mediana: 22.0, Máxima: 22.0, Mínima: 22.0

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
# Converter a coluna DTNASC para o tipo datetime
df["DTNASC"] = pd.to_datetime(df["DTNASC"], dayfirst=True)

# Filtrar os nascimentos no mês de março
sinasc_marco = df[df["DTNASC"].dt.month == 3]
sinasc_marco
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 3           1  2516500.0      110001        1        30        5.0
# 4           1  2516500.0      110001        1        30        2.0
# 5           1  2516500.0      110001        1        33        5.0
# 9           1  2679477.0      110001        1        30        2.0
# 10          1  2679477.0      110001        1        31        5.0
# ...       ...        ...         ...      ...       ...        ...
# 13670       1  2000733.0      120040        1        24        5.0
# 13671       1  2000733.0      120040        1        24        5.0
# 13736       1  2688611.0      355030        1        35        2.0
# 13748       1  2311682.0      510340        1        36        4.0
# 13750       1  2604388.0      510340        1        31        2.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 3      12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4          8 a 11 anos    999992.0         1.0         0.0  ...           5
# 5           1 a 3 anos    621005.0         2.0         1.0  ...           5
# 9           1 a 3 anos    999992.0         1.0         1.0  ...           5
# 10         8 a 11 anos    512105.0         1.0         0.0  ...           5
# ...                ...         ...         ...         ...  ...         ...
# 13670      8 a 11 anos    999992.0         0.0         0.0  ...           5
# 13671       4 a 7 anos    999992.0         2.0         0.0  ...           9
# 13736  12 anos ou mais     10210.0         1.0         0.0  ...           5
# 13748  12 anos ou mais    354605.0         2.0         1.0  ...           5
# 13750  12 anos ou mais    142305.0         0.0         1.0  ...           5
#
#       CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 3            4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4            5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 5            6        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 9           10        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 10          11        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...        ...          ...        ...                      ...       ...
# 13670    18687        ATIVO      MUNIC              Porto Velho  Rondônia
# 13671    18702        ATIVO      MUNIC              Porto Velho  Rondônia
# 13736  1066018        ATIVO      MUNIC              Porto Velho  Rondônia
# 13748  1386627        ATIVO      MUNIC                  Vilhena  Rondônia
# 13750  1388221        ATIVO      MUNIC                Ji-Paraná  Rondônia
#
#        munResLat munResLon  munResAlt  munResArea
# 3      -12.13178 -61.85308      397.0    3958.273
# 4      -11.93554 -61.99982      338.0    7067.025
# 5      -11.93554 -61.99982      338.0    7067.025
# 9      -11.93554 -61.99982      338.0    7067.025
# 10     -11.93554 -61.99982      338.0    7067.025
# ...          ...       ...        ...         ...
# 13670   -8.76889 -63.83145       87.0   34096.394
# 13671   -8.76889 -63.83145       87.0   34096.394
# 13736   -8.76889 -63.83145       87.0   34096.394
# 13748  -12.74137 -60.13858      595.0   11518.915
# 13750  -10.88205 -61.94509      157.0    6896.648
#
# [2456 rows x 69 columns]

# %%
#Encontrar o município com mais nascimentos em março
municipio_mais_bebes = sinasc_marco["munResNome"].value_counts().idxmax()
municipio_mais_bebes

print(f"Município com mais nascimentos em março: {municipio_mais_bebes}")
# Out:
# Município com mais nascimentos em março: Porto Velho

# %%
# Filtrar os dados pelo município encontrado
sinasc_municipio = sinasc_marco[sinasc_marco["munResNome"] == municipio_mais_bebes]
sinasc_municipio
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 612         1  2494299.0      110002        1        19        5.0
# 700         1  2494299.0      110002        1        19        5.0
# 3232        1  2808609.0      110011        1        34        5.0
# 3238        1  2808609.0      110011        1        24        5.0
# 6818        1  2515369.0      110020        1        38        2.0
# ...       ...        ...         ...      ...       ...        ...
# 13668       1  2000733.0      120040        1        19        5.0
# 13669       1  2000733.0      120040        1        21        5.0
# 13670       1  2000733.0      120040        1        24        5.0
# 13671       1  2000733.0      120040        1        24        5.0
# 13736       1  2688611.0      355030        1        35        2.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 612         4 a 7 anos    999992.0         0.0         0.0  ...           3
# 700         4 a 7 anos    622020.0         1.0         0.0  ...           4
# 3232           Nenhuma    622020.0         0.0         1.0  ...           4
# 3238       8 a 11 anos    622020.0         1.0         0.0  ...           5
# 6818   12 anos ou mais    999991.0         2.0         1.0  ...           5
# ...                ...         ...         ...         ...  ...         ...
# 13668       4 a 7 anos    999992.0         1.0         0.0  ...           3
# 13669       4 a 7 anos    999992.0         0.0         0.0  ...           9
# 13670      8 a 11 anos    999992.0         0.0         0.0  ...           5
# 13671       4 a 7 anos    999992.0         2.0         0.0  ...           9
# 13736  12 anos ou mais     10210.0         1.0         0.0  ...           5
#
#       CONTADOR munResStatus munResTipo   munResNome  munResUf  munResLat  \
# 612        618        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
# 700        706        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
# 3232      3257        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
# 3238      3263        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
# 6818      6864        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
# ...        ...          ...        ...          ...       ...        ...
# 13668    18630        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
# 13669    18667        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
# 13670    18687        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
# 13671    18702        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
# 13736  1066018        ATIVO      MUNIC  Porto Velho  Rondônia   -8.76889
#
#       munResLon  munResAlt  munResArea
# 612   -63.83145       87.0   34096.394
# 700   -63.83145       87.0   34096.394
# 3232  -63.83145       87.0   34096.394
# 3238  -63.83145       87.0   34096.394
# 6818  -63.83145       87.0   34096.394
# ...         ...        ...         ...
# 13668 -63.83145       87.0   34096.394
# 13669 -63.83145       87.0   34096.394
# 13670 -63.83145       87.0   34096.394
# 13671 -63.83145       87.0   34096.394
# 13736 -63.83145       87.0   34096.394
#
# [744 rows x 69 columns]

# %%
# Calcular os valores de interesse para a quantidade de filhos vivos
qtd_filhos_vivos_media = sinasc_municipio["QTDFILVIVO"].mean()
qtd_filhos_vivos_mediana = sinasc_municipio["QTDFILVIVO"].median()
qtd_filhos_vivos_maxima = sinasc_municipio["QTDFILVIVO"].max()
qtd_filhos_vivos_minima = sinasc_municipio["QTDFILVIVO"].min()

print(f"Quantidade de filhos vivos - Média: {qtd_filhos_vivos_media}, Mediana: {qtd_filhos_vivos_mediana}, Máxima: {qtd_filhos_vivos_maxima}, Minima: {qtd_filhos_vivos_minima}")
# Out:
# Quantidade de filhos vivos - Média: 1.2950558213716108, Mediana: 1.0, Máxima: 9.0, Minima: 0.0

# %%
# Calcular os valores de interesse para a idade dos pais
idade_pais_media = sinasc_municipio["IDADEPAI"].mean()
idade_pais_mediana = sinasc_municipio["IDADEPAI"].median()
idade_pais_maxima = sinasc_municipio["IDADEPAI"].max()
idade_pais_minima = sinasc_municipio["IDADEPAI"].min()

print(f"Idade dos pais - Média: {idade_pais_media}, Mediana: {idade_pais_mediana}, Máxima: {idade_pais_maxima}, Minima: {idade_pais_minima}")
# Out:
# Idade dos pais - Média: 34.62903225806452, Mediana: 34.0, Máxima: 62.0, Minima: 19.0

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %%
# Calcular o número total de filhos (vivos) por município
filhos_por_municipio = df.groupby('munResNome')['QTDFILVIVO'].sum()
filhos_por_municipio
# Out:
# munResNome
# Alta Floresta D'Oeste         310.0
# Alto Alegre dos Parecis       138.0
# Alto Paraíso                  257.0
# Alvorada D'Oeste              197.0
# Ariquemes                    1657.0
# Buritis                       528.0
# Cabixi                         61.0
# Cacaulândia                    76.0
# Cacoal                       1230.0
# Campo Novo de Rondônia        152.0
# Candeias do Jamari            433.0
# Castanheiras                   34.0
# Cerejeiras                    230.0
# Chupinguaia                   173.0
# Colorado do Oeste             200.0
# Corumbiara                    107.0
# Costa Marques                 287.0
# Cujubim                       255.0
# Espigão D'Oeste               627.0
# Governador Jorge Teixeira      83.0
# Guajará-Mirim                1187.0
# Itapuã do Oeste               141.0
# Jaru                          779.0
# Ji-Paraná                    2028.0
# Machadinho D'Oeste            546.0
# Ministro Andreazza             92.0
# Mirante da Serra              152.0
# Monte Negro                   190.0
# Município ignorado - RO         1.0
# Nova Brasilândia D'Oeste      227.0
# Nova Mamoré                   513.0
# Nova União                     87.0
# Novo Horizonte do Oeste        81.0
# Ouro Preto do Oeste           563.0
# Parecis                        56.0
# Pimenta Bueno                 527.0
# Pimenteiras do Oeste           46.0
# Porto Velho                  8543.0
# Presidente Médici             280.0
# Primavera de Rondônia          47.0
# Rio Crespo                     59.0
# Rolim de Moura                789.0
# Santa Luzia D'Oeste           116.0
# Seringueiras                  147.0
# São Felipe D'Oeste             41.0
# São Francisco do Guaporé      325.0
# São Miguel do Guaporé         311.0
# Teixeirópolis                  55.0
# Theobroma                      86.0
# Urupá                         160.0
# Vale do Anari                 108.0
# Vale do Paraíso                55.0
# Vilhena                      1454.0
# Name: QTDFILVIVO, dtype: float64

# %%
# Identificar o município com o maior número total de filhos
municipio_mais_filhos = filhos_por_municipio.idxmax()
total_filhos = filhos_por_municipio.max()
total_filhos
# Out:
# 8543.0

# %%
# Calcular o número total de nascimentos por município
nascimentos_por_municipio = df['munResNome'].value_counts()
nascimentos_por_municipio
# Out:
# munResNome
# Porto Velho                  8437
# Ji-Paraná                    2182
# Ariquemes                    1729
# Vilhena                      1590
# Cacoal                       1374
# Rolim de Moura                927
# Jaru                          881
# Guajará-Mirim                 781
# Ouro Preto do Oeste           631
# Pimenta Bueno                 616
# Buritis                       583
# Machadinho D'Oeste            500
# Espigão D'Oeste               450
# Nova Mamoré                   432
# Alta Floresta D'Oeste         367
# São Miguel do Guaporé         353
# Candeias do Jamari            337
# Presidente Médici             304
# São Francisco do Guaporé      303
# Nova Brasilândia D'Oeste      261
# Cerejeiras                    237
# Costa Marques                 233
# Alto Paraíso                  226
# Colorado do Oeste             214
# Alvorada D'Oeste              205
# Cujubim                       205
# Monte Negro                   199
# Urupá                         170
# Seringueiras                  168
# Campo Novo de Rondônia        166
# Mirante da Serra              164
# Chupinguaia                   162
# Alto Alegre dos Parecis       154
# Corumbiara                    127
# Governador Jorge Teixeira     112
# Itapuã do Oeste               109
# Nova União                    104
# Santa Luzia D'Oeste            99
# Novo Horizonte do Oeste        98
# Theobroma                      97
# Vale do Anari                  93
# Ministro Andreazza             84
# Vale do Paraíso                81
# Cabixi                         80
# Cacaulândia                    75
# Teixeirópolis                  64
# São Felipe D'Oeste             54
# Rio Crespo                     50
# Parecis                        44
# Primavera de Rondônia          43
# Pimenteiras do Oeste           40
# Castanheiras                   32
# Município ignorado - RO         1
# Name: count, dtype: int64

# %% [markdown]
# Devido à maior quantidade de habitantes em Porto Velho e à sua taxa de natalidade mais elevada em comparação com outros municípios, é o município com o maior número de bebês nascidos em março.

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# 0      Masculino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 1       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 2       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 3       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# 4       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# ...          ...     ...         ...       ...        ...         ...
# 27023  Masculino  Branca  2020-09-28       NaN     3.2.01  2020-10-13
# 27024  Masculino  Branca  2019-10-16       NaN     3.2.01  2019-10-21
# 27025  Masculino   Parda  2019-08-07       NaN     3.2.00  2019-08-07
# 27026  Masculino   Parda  2020-01-07       NaN     3.2.00  2020-01-07
# 27027  Masculino   Parda  2020-10-15       NaN     3.2.01  2020-10-16
#
#       munResStatus munResTipo               munResNome  munResUf
# 0            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3            ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...            ...        ...                      ...       ...
# 27023        ATIVO      MUNIC                  Vilhena  Rondônia
# 27024        ATIVO      MUNIC              Chupinguaia  Rondônia
# 27025        ATIVO      MUNIC                  Vilhena  Rondônia
# 27026        ATIVO      MUNIC                  Vilhena  Rondônia
# 27027        ATIVO      MUNIC  Novo Horizonte do Oeste  Rondônia
#
# [27028 rows x 15 columns]

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
#        'munResUf', 'munResLat', 'munResLon', 'munResAlt', 'munResArea'],
#       dtype='object')
